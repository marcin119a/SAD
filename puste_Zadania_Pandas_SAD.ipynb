# %% [markdown]
# <a href="https://colab.research.google.com/github/marcin119a/SAD/blob/main/puste_Zadania_Pandas_SAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Zadanie 1:
# Wczytaj zbiór danych tips.csv i wyświetl pierwsze 10 wierszy danych.
# * Zadanie 2:
# Wyświetl kolumny total_bill oraz tip dla pierwszych 5 wierszy.
# Filtruj dane, aby wyświetlić tylko rachunki mniejsze niż 20.
# * Zadanie 3:
# Stwórz nową kolumnę, która będzie zawierać procent napiwku względem całkowitego rachunku.
# Stwórz nową kolumnę, która będzie reprezentować średni rachunek na osobę.
# * Zadanie 4:
# Oblicz średnią oraz medianę dla kolumny total_bill.
# Oblicz modę dla zmiennej sex.
# * Zadanie 5:
# Znajdź dzień tygodnia, w którym średni napiwek jest najwyższy.
# Porównaj średnią wartość napiwku dla grup o różnej liczbie osób przy stole.
# * Zadanie 6:
# Stwórz histogram dla kolumny total_bill.
# Stwórz wykres punktowy (scatter plot), który porównuje total_bill i tip.
# * Zadanie 7:
# Wyświetl rachunki mniejsze niż 20 oraz napiwki mniejsze niż 2.
# Wyświetl rachunki większe od średniego rachunku.

# %%
import pandas as pd
tips = pd.read_csv('https://raw.githubusercontent.com/marcin119a/SAD/refs/heads/main/tips.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# * Zadanie 1:
# Wczytaj zbiór danych income.csv i wyświetl pierwsze 10 wierszy danych.
# * Zadanie 2:
# Wyświetl kolumny Country oraz GDP per capita dla pierwszych 5 wierszy.
# Filtruj dane, aby wyświetlić tylko kraje o GDP per capita większym niż 5000.
# * Zadanie 3:
# Stwórz nową kolumnę, która będzie zawierać stosunek GDP per capita do Population.
# Stwórz nową kolumnę, która będzie reprezentować przewidywaną długość życia na 1000 mieszkańców (Life expectancy * 1000 / Population).
# * Zadanie 4
# Oblicz średnią oraz medianę dla kolumny GDP per capita.
# Oblicz modę dla zmiennej Continent.
# * Zadanie 5
# Znajdź kontynent, który ma najwyższe średnie GDP per capita.
# Porównaj średnią długość życia (Life expectancy) dla różnych kontynentów.
# * Zadanie 6
# Stwórz histogram dla kolumny GDP per capita.
# Stwórz wykres punktowy (scatter plot), który porównuje GDP per capita i Life expectancy.
# * Zadanie 7
# Wyświetl kraje, w których Life expectancy jest większe niż 70 lat i GDP per capita większe niż 10000.
# Wyświetl kraje, w których Population jest większa od średniej liczby ludności dla całego

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/marcin119a/SAD/refs/heads/main/income.csv', sep=';')
df
# Out:
#                       Country  GDP per capita  Life expectancy  Population  \
# 0                     Lesotho            2598            47.10     2174645
# 1    Central African Republic             599            49.60     4546100
# 2                   Swaziland            6095            51.80     1319011
# 3                 Afghanistan            1925            53.80    33736494
# 4                     Somalia             624            54.20    13908129
# ..                        ...             ...              ...         ...
# 187               Switzerland           56118            83.00     8282396
# 188                     Japan           36162            83.20   127141000
# 189                   Iceland           42182            83.30      330815
# 190          Hong Kong, China           53874            83.73     7291300
# 191                   Andorra           46577            84.80       78014
#
#     Continent
# 0      Africa
# 1      Africa
# 2      Africa
# ...
